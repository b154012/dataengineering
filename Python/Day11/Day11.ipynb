# %% [markdown]
# # Day 11: Python
#
# ***
#
# ### 1. Write a program to realise the function of tail – f.
# <br>
#
# The basic implementation of the function of tail -f.
# * It reads the contents of a specified file from the bottom up to nth position.
# * For example, input is python tail.py data1.txt 5.
# * Runs the program on the command line.

# %%
import sys
import os

def tail(filename, numlines):

    #read the file
    with open(filename, 'r') as file:
        #store each line in a list
        content = file.read().splitlines()
        
    #count the length of list
    count = len(filename)
    
    #display content using loop
    for i in range(count-numlines, count):
        print(content[i])

def main():
    if len(sys.argv) != 3:
        print("Usage: python tail.py <file_name> <number_line>")
    else:
        tail(sys.argv[1], int(sys.argv[2]))

if __name__ == '__main__':
    main()

# %% [markdown]
# ***
#
#
# ### 2. Create a data frame (df) by using the data file Euro2012.csv (in Teams shared folder).
# <br>

# %%
import pandas as pd

df = pd.read_csv('Euro2012.csv')
df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ***
#
# ### 3. How many teams participated in Euro 2012?
# <br>

# %%
print("The number of teams participated in Euro 2012 is", df['Team'].count())
# Out:
# The number of teams participated in Euro 2012 is 16

# %% [markdown]
# ***
# ### 4. How many columns are there in the dataset?
# <br>

# %%
print("There are", len(df.columns),"columns in the dataset.")
# Out:
# There are 35 columns in the dataset.

# %% [markdown]
# ***
# ### 5. Save the columns Team, Yellow Cards and Red Cards in the dataset as a separate df called discipline. <br>
# <br>

# %%
df_discipline = df.loc[:, ['Team', 'Yellow Cards', 'Red Cards']]
df_discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
df_discipline.head(5)
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
df_discipline.tail(5)
# Out:
#                    Team  Yellow Cards  Red Cards
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
df_discipline.shape
# Out:
# (16, 3)

# %%
df_discipline.describe()
# Out:
#        Yellow Cards  Red Cards
# count     16.000000  16.000000
# mean       7.437500   0.187500
# std        3.265348   0.403113
# min        4.000000   0.000000
# 25%        5.000000   0.000000
# 50%        6.500000   0.000000
# 75%        9.000000   0.000000
# max       16.000000   1.000000

# %% [markdown]
# ***
# ### 6. Sort the df discipline by Red Cards first, and then by Yellow Cards.
# <br>

# %%
#sort the Red Cards first from lowest to highest, set it to 1
#sort the Yellow Cards next from higest to lowest, set it to 0
df_discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending=[1,0])
# Out:
#                    Team  Yellow Cards  Red Cards
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1

# %% [markdown]
# ***
# ### 7. Calculate the average number of yellow cards for each team. </b>
# <br>

# %%
avg = df_discipline['Yellow Cards'].mean()
print("The average number of yellow cards for each team is ", avg)
# Out:
# The average number of yellow cards for each team is  7.4375

# %% [markdown]
# ***
#
# ### 8. Find teams with Goals over 6.
# <br>

# %%
# 8. Find teams with Goals over 6.

teams_goals_over6 = df.loc[df['Goals'] > 6]
teams_goals_over6 = teams_goals_over6.loc[:, ['Team','Goals']]
print("Teams with Goals over 6:")
teams_goals_over6
# Out:
# Teams with Goals over 6:
#        Team  Goals
# 5   Germany     10
# 13    Spain     12

# %% [markdown]
# ***
#
# ### 9. Select the team data that begins with the letter G.
# <br>

# %%
import re

team_begins_G_letter = df.loc[df['Team'].str.contains(r'^G+', flags=re.I, regex=True)]
print("The team data that begins with the letter G is")
team_begins_G_letter
# Out:
# The team data that begins with the letter G is
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# ...

# %% [markdown]
# ***
# ### 10. Select all columns except the last three.</b>
# <br>

# %%
allcolumns_except_last_3 = df.iloc[:, 0:-3]
row, col = allcolumns_except_last_3.shape
print("There are", row, "rows and", col, "columns.")

print("All columns except the last three are ")
allcolumns_except_last_3
# Out:
# There are 16 rows and 32 columns.
# All columns except the last three are
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# ...
